# %%
# -*- coding: utf-8 -*-
"""Untitled16.ipynb

Automatically generated by Colaboratory.

Original file is located at
    https://colab.research.google.com/drive/1c6qA5E85DCut8yemaUmF5qLRqKid4dUa
"""

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Your data
data = pd.read_csv("corona virus data.csv")

# Creating a DataFrame
df = pd.DataFrame(data)

# Set a light background color
sns.set_theme(style="whitegrid")

# Displaying summary statistics
summary_stats = df.describe()

# Visualizing data
plt.figure(figsize=(15, 10))


# Bar plot for Total Confirmed cases
plt.subplot(2, 2, 1)
sns.barplot(x='Confirmed', y='Country/Region', data=df, palette='viridis')
plt.title('Total Confirmed Cases by Country')

# Donut plot for Deaths/Recovered percentage
plt.subplot(2, 2, 2)
plt.pie([df['Deaths'].sum(), df['Recovered'].sum()], labels=['Deaths', 'Recovered'], autopct='%1.1f%%', colors=['red', 'green'], startangle=90)
plt.title('Deaths vs Recovered Percentage')

# Horizontal bar plot for New cases
plt.subplot(2, 2, 3)
sns.barplot(x='New cases', y='Country/Region', data=df, palette='muted')
plt.title('New Cases by Country')

# Trend line for Confirmed cases
plt.subplot(2, 2, 4)
sns.lineplot(x='Country/Region', y='Confirmed', data=df, marker='o', color='purple')
plt.title('Trend of Confirmed Cases')

# Rotate x-axis labels for better readability
plt.xticks(rotation=45, ha='right')

plt.tight_layout(pad=7)
plt.suptitle('          Corona Virus Trends \n Name:Narender Reddy Yellu        Student ID:22085308', fontsize=19, fontweight='bold')
plt.show()
